# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/Users/iuliarusu/Documents/YeastSAGA_IDR.csv')

# %%
df.shape
# Out:
# (19, 3745)

# %%
df
# Out:
#    ProteinSubunit  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# 0            Gcn5      0.7073      0.6663      0.6544      0.6633      0.6851
# 1            Ada2      0.0233      0.0189      0.0195      0.0230      0.0280
# 2     Ngg1 (Ada3)      0.9090      0.9017      0.8960      0.8911      0.8866
# 3           Sgf29      0.1445      0.1332      0.1338      0.1410      0.1509
# 4            Ubp8      0.0232      0.0105      0.0280      0.0587      0.0907
# 5           Sgf11      0.3418      0.3929      0.4061      0.3973      0.3781
# 6           Sgf73      0.4476      0.5107      0.5333      0.5312      0.5163
# 7            Sus1      0.4750      0.4499      0.4094      0.3679      0.3341
# 8            Taf5      0.9511      0.9513      0.9548      0.9597      0.9645
# 9            Taf6      0.1963      0.2952      0.3542      0.3870      0.4039
# 10           Taf9      0.5272      0.5724      0.5756      0.5569      0.5308
# ...

# %%
lengths = [len(df.columns)] * len(df)

# %%
lengths
# Out:
# [3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745,
#  3745]

# %%
#non Nan lengths
def non_nan_length(row):
    non_nan_values = row.dropna()
    return len(non_nan_values)

# %%
lengths_without_Nan = df.apply(non_nan_length, axis=1)

# %%
lengths_without_Nan
# Out:
# 0      440
# 1      435
# 2      703
# 3      260
# 4      472
# 5      100
# 6      658
# 7       97
# 8      799
# 9      517
# 10     158
# 11     207
# 12     540
# 13    1333
# 14     489
# 15     605
# 16     338
# 17     603
# 18    3745
# dtype: int64

# %%
#check if above is a dataframe
if isinstance(lengths_without_Nan, pd.DataFrame):
    print("df is a DataFrame!")
else:
    print("df is not a DataFrame!")

#make a histogram to check the data distribution for better heatmap binning
#lengths_without_Nan = pd.DataFrame(lengths_without_Nan, columns=['Lengths'])
# Out:
# df is not a DataFrame!

# %%
type(lengths_without_Nan)
lengths_without_Nan
# Out:
# 0      440
# 1      435
# 2      703
# 3      260
# 4      472
# 5      100
# 6      658
# 7       97
# 8      799
# 9      517
# 10     158
# 11     207
# 12     540
# 13    1333
# 14     489
# 15     605
# 16     338
# 17     603
# 18    3745
# dtype: int64

# %%
#make into a dataframe to graph it
#make a histogram to check the data distribution for better heatmap binning
lengths_without_Nan_data = pd.DataFrame(lengths_without_Nan, columns=['Lengths'])

# %%
# Creating the histogram
subunits_distribution = lengths_without_Nan_data['Lengths'].hist(bins=20, edgecolor='black')

# Adding labels and title for better readability
plt.xlabel('Length')
plt.ylabel('Frequency')
plt.title('Distribution of Lengths')

# Showing the plot
plt.show()

# %%
df.set_index("ProteinSubunit",inplace=True)

# %%
df.iloc[0:2]
# Out:
#                 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ProteinSubunit
# Gcn5                0.7073      0.6663      0.6544      0.6633      0.6851
# Ada2                0.0233      0.0189      0.0195      0.0230      0.0280
#
#                 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ProteinSubunit
# Gcn5                0.7132      0.7419      0.7665      0.7835       0.7908
# Ada2                0.0331      0.0374      0.0401      0.0410       0.0398
#
#                 ...  Unnamed: 3735  Unnamed: 3736  Unnamed: 3737  \
# ProteinSubunit  ...
# Gcn5            ...            NaN            NaN            NaN
# Ada2            ...            NaN            NaN            NaN
#
#                 Unnamed: 3738  Unnamed: 3739  Unnamed: 3740  Unnamed: 3741  \
# ProteinSubunit
# Gcn5                      NaN            NaN            NaN            NaN
# Ada2                      NaN            NaN            NaN            NaN
#
# ...

# %%
# Adding a new column that stores the count of non-NaN values in each row
df['NonNaNCount'] = df.apply(non_nan_length, axis=1)

# %%
df
# Out:
#                 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ProteinSubunit
# Gcn5                0.7073      0.6663      0.6544      0.6633      0.6851
# Ada2                0.0233      0.0189      0.0195      0.0230      0.0280
# Ngg1 (Ada3)         0.9090      0.9017      0.8960      0.8911      0.8866
# Sgf29               0.1445      0.1332      0.1338      0.1410      0.1509
# Ubp8                0.0232      0.0105      0.0280      0.0587      0.0907
# Sgf11               0.3418      0.3929      0.4061      0.3973      0.3781
# Sgf73               0.4476      0.5107      0.5333      0.5312      0.5163
# Sus1                0.4750      0.4499      0.4094      0.3679      0.3341
# Taf5                0.9511      0.9513      0.9548      0.9597      0.9645
# Taf6                0.1963      0.2952      0.3542      0.3870      0.4039
# Taf9                0.5272      0.5724      0.5756      0.5569      0.5308
# ...

# %%
# Using boolean indexing to select rows based on the count of non-NaN values
small_subunits = df[df['NonNaNCount'] < 300]

# Dropping the 'NonNaNCount' column if you don't want it in the result
small_subunits = small_subunits.drop(columns=['NonNaNCount'])

# %%
small_subunits
# Out:
#                 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ProteinSubunit
# Sgf29               0.1445      0.1332      0.1338      0.1410      0.1509
# Sgf11               0.3418      0.3929      0.4061      0.3973      0.3781
# Sus1                0.4750      0.4499      0.4094      0.3679      0.3341
# Taf9                0.5272      0.5724      0.5756      0.5569      0.5308
# Taf10               0.4391      0.5138      0.5724      0.6183      0.6542
#
#                 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ProteinSubunit
# Sgf29               0.1606      0.1685      0.1739      0.1770       0.1782
# Sgf11               0.3560      0.3352      0.3174      0.3024       0.2884
# Sus1                0.3126      0.3038      0.3056      0.3138       0.3235
# Taf9                0.5070      0.4912      0.4858      0.4905       0.5032
# Taf10               0.6820      0.7035      0.7196      0.7313       0.7389
#
# ...

# %%
#defining the rest of the subunit categories by length segregation
medium_subunits = df[(df['NonNaNCount'] >= 301) & (df['NonNaNCount'] <= 500)]
medium_subunits = medium_subunits.drop(columns=['NonNaNCount'])

# %%
medium_subunits
# Out:
#                 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ProteinSubunit
# Gcn5                0.7073      0.6663      0.6544      0.6633      0.6851
# Ada2                0.0233      0.0189      0.0195      0.0230      0.0280
# Ubp8                0.0232      0.0105      0.0280      0.0587      0.0907
# Hfi1(Ada1)          0.6664      0.6693      0.6656      0.6577      0.6481
# Spt3                0.2627      0.3602      0.3839      0.3666      0.3321
#
#                 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ProteinSubunit
# Gcn5                0.7132      0.7419      0.7665      0.7835       0.7908
# Ada2                0.0331      0.0374      0.0401      0.0410       0.0398
# Ubp8                0.1168      0.1333      0.1397      0.1377       0.1302
# Hfi1(Ada1)          0.6393      0.6332      0.6315      0.6353       0.6451
# Spt3                0.2970      0.2713      0.2596      0.2627       0.2780
#
# ...

# %%
big_subunits = df[(df['NonNaNCount'] >= 501) & (df['NonNaNCount'] <= 1000)]
big_subunits = big_subunits.drop(columns=['NonNaNCount'])

# %%
big_subunits
# Out:
#                 Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  \
# ProteinSubunit
# Ngg1 (Ada3)         0.9090      0.9017      0.8960      0.8911      0.8866
# Sgf73               0.4476      0.5107      0.5333      0.5312      0.5163
# Taf5                0.9511      0.9513      0.9548      0.9597      0.9645
# Taf6                0.1963      0.2952      0.3542      0.3870      0.4039
# Taf12               0.8867      0.8918      0.8935      0.8947      0.8972
# Spt20               0.9755      0.9764      0.9445      0.8989      0.8532
# Spt8                0.9095      0.9035      0.9009      0.9026      0.9087
#
#                 Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  Unnamed: 10  \
# ProteinSubunit
# Ngg1 (Ada3)         0.8826      0.8791      0.8762      0.8744       0.8737
# Sgf73               0.4969      0.4783      0.4636      0.4539       0.4489
# Taf5                0.9686      0.9714      0.9730      0.9735       0.9733
# ...

# %%
largest_subunits = df[df['NonNaNCount'] > 1001]
largest_subunits = largest_subunits.drop(columns=['NonNaNCount'])

# %%
# plt.figure(figsize=(100, 50))
# plt.figure(figsize=(100, 50))
nperplot = 5
for i, (row_ind, row) in enumerate(small_subunits.iterrows()):
    vals = row.values
    vals = vals[:len(vals) - np.isnan(vals).sum()]
    normed_xvals = np.linspace(0, 1, len(vals))
    plt.plot(normed_xvals, vals, label=row.name, alpha=0.5)
    if i % nperplot == 0 and i != 0:
        plt.legend()
        plt.xlabel("Percentage along protein")
        plt.ylabel("Disorder score")
        plt.show()

plt.legend()
plt.xlabel("Percentage along protein")
plt.ylabel("Disorder score")
plt.show()

# %%
plt.figure(figsize=(40, 10))

def remove_nan_vals(row):
    vals = row.values
    cleaned_vals = vals[~np.isnan(vals)]
    return pd.Series(cleaned_vals)
   

new_df1 = medium_subunits.apply(remove_nan_vals, axis=1)
plt.yticks(range(len(new_df1)), list(new_df1.index))
plt.xlabel("Amino Acid Position", fontsize=50)
plt.ylabel("Disorder score", fontsize=50)
plt.yticks(fontsize= 20)
plt.xticks(fontsize= 20)
im = plt.imshow(new_df1, cmap="rocket_r", vmax = 1, vmin = 0, aspect='auto' )
plt.colorbar(im,fraction=0.025, pad=0.04)
plt.show()

# %%
plt.figure(figsize=(40, 10))

def remove_nan_vals(row):
    vals = row.values
    cleaned_vals = vals[~np.isnan(vals)]
    return pd.Series(cleaned_vals)
   

new_df = small_subunits.apply(remove_nan_vals, axis=1)
plt.yticks(range(len(new_df)), list(new_df.index))
plt.xlabel("Amino Acid Position", fontsize=50)
plt.ylabel("Disorder score", fontsize=50)
plt.yticks(fontsize= 20)
plt.xticks(fontsize= 20)
im = plt.imshow(new_df, cmap="rocket_r", vmax = 1, vmin = 0, aspect='auto' )
plt.colorbar(im,fraction=0.025, pad=0.04)
plt.show()

# %%
plt.figure(figsize=(40, 10))

def remove_nan_vals(row):
    vals = row.values
    cleaned_vals = vals[~np.isnan(vals)]
    return pd.Series(cleaned_vals)
   

new_df2 = big_subunits.apply(remove_nan_vals, axis=1)
plt.yticks(range(len(new_df2)), list(new_df2.index))
plt.xlabel("Amino Acid Position", fontsize=50)
plt.ylabel("Disorder score", fontsize=50)
plt.yticks(fontsize= 20)
plt.xticks(fontsize= 20)
im = plt.imshow(new_df2, cmap="rocket_r", vmax = 1, vmin = 0, aspect='auto' )
plt.colorbar(im,fraction=0.025, pad=0.04)
plt.show()

# %%
plt.figure(figsize=(200, 50))

def remove_nan_vals(row):
    vals = row.values
    cleaned_vals = vals[~np.isnan(vals)]
    return pd.Series(cleaned_vals)

new_df3 = largest_subunits.apply(remove_nan_vals, axis=1)
plt.yticks(range(len(new_df3)), list(new_df3.index), fontsize=100)
plt.xlabel("Amino Acid Position", fontsize=200)
plt.ylabel("Disorder score", fontsize=200)
plt.yticks(range(len(new_df3)), new_df3.index, fontsize=150)
plt.xticks(fontsize= 100)
im = plt.imshow(new_df3, cmap="rocket_r", vmax = 1, vmin = 0, aspect = 'auto')
cbar = plt.colorbar(im,fraction=0.025, pad=0.04 )
cbar.ax.tick_params(labelsize=100)
plt.show()

# %%
npixels = 50
perc_interval = npixels // 10
plt.figure(figsize=(10, 10))


def chunk_vals(row):
    vals = row.values
    vals = vals[:len(vals)-np.isnan(vals).sum()]
    chunked_vals = np.array_split(vals, npixels)
    return [np.mean(chunk) for chunk in chunked_vals]

chunked_lists = df.apply(chunk_vals, axis=1)

res = np.stack(chunked_lists.values)


plt.imshow(res, cmap="viridis", vmax=1, vmin=0)
plt.yticks(range(len(df)), list(df.index))

all_nones  = [None]*npixels
for i in range(npixels):
    if i%perc_interval==0:
        all_nones[i] = round(i/npixels,2)
all_nones[-1] = 1.0
plt.xticks(range(0,npixels), all_nones)

plt.xlabel("Percentage along protein")
plt.ylabel("Disorder score")
im = plt.imshow(res, cmap="viridis", vmax=1, vmin=0)
plt.colorbar(im,fraction=0.015, pad=0.04)
plt.show()
